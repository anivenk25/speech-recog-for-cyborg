5 kB/s eta 0:00:06
#      --------------------------- ----------- 9.1/12.8 MB 746.4 kB/s eta 0:00:05
#      ---------------------------- ---------- 9.2/12.8 MB 752.7 kB/s eta 0:00:05
#      ---------------------------- ---------- 9.3/12.8 MB 756.5 kB/s eta 0:00:05
#      ---------------------------- ---------- 9.3/12.8 MB 758.7 kB/s eta 0:00:05
#      ---------------------------- ---------- 9.3/12.8 MB 758.7 kB/s eta 0:00:05
#      ---------------------------- ---------- 9.5/12.8 MB 761.9 kB/s eta 0:00:05
#      ----------------------------- --------- 9.7/12.8 MB 776.4 kB/s eta 0:00:05
#      ----------------------------- --------- 9.8/12.8 MB 783.9 kB/s eta 0:00:04
#      ----------------------------- -------- 10.0/12.8 MB 790.5 kB/s eta 0:00:04
#      ----------------------------- -------- 10.1/12.8 MB 797.3 kB/s eta 0:00:04
#      ------------------------------ ------- 10.2/12.8 MB 805.9 kB/s eta 0:00:04
#      ------------------------------ ------- 10.3/12.8 MB 814.3 kB/s eta 0:00:04
#      ------------------------------- ------ 10.5/12.8 MB 828.7 kB/s eta 0:00:03
#      ------------------------------- ------ 10.5/12.8 MB 833.0 kB/s eta 0:00:03
#      ------------------------------- ------ 10.6/12.8 MB 844.8 kB/s eta 0:00:03
#      ------------------------------- ------ 10.7/12.8 MB 854.7 kB/s eta 0:00:03
#      ------------------------------- ------ 10.7/12.8 MB 854.7 kB/s eta 0:00:03
#      -------------------------------- ----- 11.0/12.8 MB 904.2 kB/s eta 0:00:02
#      --------------------------------- ---- 11.1/12.8 MB 965.6 kB/s eta 0:00:02
#      --------------------------------- ---- 11.2/12.8 MB 993.5 kB/s eta 0:00:02
#      ----------------------------------- ---- 11.3/12.8 MB 1.1 MB/s eta 0:00:02
#      ----------------------------------- ---- 11.3/12.8 MB 1.1 MB/s eta 0:00:02
#      ----------------------------------- ---- 11.3/12.8 MB 1.1 MB/s eta 0:00:02
#      ------------------------------------ --- 11.5/12.8 MB 1.2 MB/s eta 0:00:02
#      ------------------------------------ --- 11.6/12.8 MB 1.2 MB/s eta 0:00:02
#      ------------------------------------ --- 11.6/12.8 MB 1.2 MB/s eta 0:00:01
#      ------------------------------------ --- 11.8/12.8 MB 1.3 MB/s eta 0:00:01
#      ------------------------------------- -- 11.9/12.8 MB 1.3 MB/s eta 0:00:01
#      ------------------------------------- -- 11.9/12.8 MB 1.3 MB/s eta 0:00:01
#      ------------------------------------- -- 11.9/12.8 MB 1.3 MB/s eta 0:00:01
#      ------------------------------------- -- 12.0/12.8 MB 1.3 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/12.8 MB 1.3 MB/s eta 0:00:01
#      ------------------------------------- -- 12.1/12.8 MB 1.3 MB/s eta 0:00:01
#      -------------------------------------- - 12.2/12.8 MB 1.4 MB/s eta 0:00:01
#      -------------------------------------- - 12.2/12.8 MB 1.4 MB/s eta 0:00:01
#      -------------------------------------- - 12.3/12.8 MB 1.4 MB/s eta 0:00:01
#      -------------------------------------- - 12.4/12.8 MB 1.4 MB/s eta 0:00:01
#      ---------------------------------------  12.5/12.8 MB 1.4 MB/s eta 0:00:01
#      ---------------------------------------  12.6/12.8 MB 1.4 MB/s eta 0:00:01
#      ---------------------------------------  12.7/12.8 MB 1.4 MB/s eta 0:00:01
#      ---------------------------------------  12.7/12.8 MB 1.4 MB/s eta 0:00:01
#      ---------------------------------------  12.8/12.8 MB 1.5 MB/s eta 0:00:01
#      ---------------------------------------  12.8/12.8 MB 1.5 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.6.3)
# Requirement already satisfied: jinja2 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.3)
# Requirement already satisfied: setuptools in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (68.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aniru\pycharmprojects\meeting notes\venv\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.7.1
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import speech_recognition as sr
import requests
from bs4 import BeautifulSoup
import spacy
from collections import Counter
from heapq import nlargest
import string
import datetime

# Load the English NLP model
nlp = spacy.load("en_core_web_sm")

def recognize_speech(language='en-IN'):
  """
  Recognizes speech input from the microphone.

  Args:
      language (str, optional): Language code for speech recognition. Defaults to 'en-IN' (English India).

  Returns:
      str: Recognized text, or None if unable to recognize.
  """

  recognizer = sr.Recognizer()

  with sr.Microphone() as source:
    print(f"Listening for {language} speech...")
    recognizer.adjust_for_ambient_noise(source, duration=1)
    audio = recognizer.listen(source)

  try:
    if language == 'en-IN':
      recognized_text = recognizer.recognize_google(audio, language=language)
    elif language == 'hi-IN':
      recognized_text = recognizer.recognize_google(audio, language=language)
    else:
      recognized_text = None
      print("Language not supported")
  except sr.UnknownValueError:
    recognized_text = None
    print("Unable to recognize speech")

  return recognized_text

def preprocess_text(text):
  """
  Preprocesses text by tokenizing, lemmatizing, and removing stop words and punctuation.

  Args:
      text (str): Text to be preprocessed.

  Returns:
      list: List of preprocessed tokens.
  """

  doc = nlp(text)
  tokens = [token.lemma_ for token in doc if not token.is_stop and not token.is_punct]
  return tokens

def extract_keywords(text, num_keywords=5):
  """
  Extracts top keywords from text using word frequency.

  Args:
      text (str): Text to extract keywords from.
      num_keywords (int, optional): Number of keywords to extract. Defaults to 5.

  Returns:
      list: List of top keywords.
  """

  word_freq = Counter(text)
  return nlargest(num_keywords, word_freq, key=word_freq.get)

def generate_summary(text, num_sentences=3):
  """
  Generates a summary of the text using spaCy's built-in summarization feature.

  Args:
      text (str): Text to summarize.
      num_sentences (int, optional): Number of sentences to include in the summary. Defaults to 3.

  Returns:
      str: Summary of the text.
  """

  doc = nlp(text)
  sentences = [sent.text for sent in doc.sents]
  summary = " ".join(sentences[:num_sentences])
  return summary

def search_web(topic):
  """
  Searches the web for news articles related to the provided topic.

  Args:
      topic (str): Topic to search for.

  Returns:
      list: List of news article snippets.
  """

  url = f"https://www.google.com/search?q={topic}&tbm=nws"
  headers = {"User-Agent": "Mozilla/5.0"}
  response = requests.get(url, headers=headers)
  soup = BeautifulSoup(response.text, 'html.parser')
  news_results = soup.find_all('div', class_='BNeawe vvjwJb AP7Wnd')
  return [result.get_text() for result in news_results]

def get_timestamp():
  """
  Returns a timestamp in YYYY-MM-DD format.

  Returns:
      str: Timestamp.
  """

  return datetime.datetime.now().strftime('%Y-%m-%d')

def save_minutes(meeting_minutes, filename="meeting_minutes.txt"):
  """
  Saves meeting minutes to a text file, with timestamps for each speech segment.

  Args:
      meeting_minutes (list): List of meeting speech segments.
      filename (str, optional): Name of the output file. Defaults to "meeting_minutes.txt".
  """

  timestamp = get_timestamp()
  with open(f"{filename}-{timestamp}", "w") as file:
    for i, speech in enumerate(meeting_minutes):
      file.write
